# %% [markdown]
# seaborn

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from seaborn) (2.4.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
df= sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('darkgrid')
sns.set_context('notebook')

# %%
sns.histplot([df["total_bill"]], bins=20,kde=True)
plt.show()

# %%
sns.kdeplot(df["total_bill"], fill=True)
plt.show()

# %%
sns.displot(df["total_bill"], bins=20, kde=True)
plt.show()

# %% [markdown]
# displot and histogram are same

# %% [markdown]
# barplot

# %%
sns.barplot(x="day", y="total_bill", data=df)
plt.show()

# %%
sns.countplot(x="day", data=df)
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=df)
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.violinplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=df)
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue='day')
plt.show()

# %%
sns.lineplot(x='size', y='total_bill', data=df)
plt.show()

# %% [markdown]
# matrixplot
# heatmap

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# cluster map

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (1.17.1)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in c:\users\hp\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from scipy) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()

# %%
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
print(scipy.__version__, scipy.__version__)
sns.clustermap(corr, annot=True)
plt.show()
# Out:
# 1.17.1 1.17.1

# %%
sns.clustermap(corr, annot=True)
plt.show()

# %%
sns.regplot(x='total_bill', y='tip', data=df)
plt.show()

# %%
sns.pairplot(df,hue = 'sex')
plt.show()

# %% [markdown]
# faceplot

# %%
g = sns.FacetGrid(df, col='time')
g.map(sns.histplot, 'total_bill')

# %%
g = sns.FacetGrid(df, col='day')
g.map(sns.histplot, 'total_bill')

# %% [markdown]
# joint plot

# %%
sns.jointplot(x='total_bill', y='tip', data=df,hue='day', kind='scatter')
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=df ,kind='scatter')
plt.show()

# %% [markdown]
# rugplot

# %%
sns.rugplot(df["total_bill"])
plt.show()

# %%
sns.rugplot(df["total_bill"])
sns.kdeplot(df["total_bill"])
plt.show()

# %%
plt.scatter(x='tip',y='total_bill')
plt.plot(df["tip"], df['total_bill'])
plt.show()
